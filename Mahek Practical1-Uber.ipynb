# %% [markdown]
# ##### Programemr: Mahek Suhail Shaikh  (BE-B  29 )
# ##### Practical 1:Predict the price of the Uber ride from a given pickup point to the agreed drop-off location.
# ##### Perform following tasks:
# 1. Pre-process the dataset.
# 2. Identify outliers.
# 3. Check the correlation.
# 4. Implement linear regression and random forest regression models.
# 5. Evaluate the models and compare their respective scores like R2, RMSE, etc.
# Dataset link: https://www.kaggle.com/datasets/yasserh/uber-fares-dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn import preprocessing

# %% [markdown]
# ## **Loading the Dataset**
# First we load the dataset and find out the number of columns, rows, NULL values, etc.

# %%
df = pd.read_csv('uber.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %% [markdown]
# ## **Pre-Processing the data (Cleaning)**

# %%
df = df.drop(['Unnamed: 0', 'key'], axis=1)    #Deleting column Unnamed: 0

# %%
df.isna().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %% [markdown]
# #### Remove null rows

# %%
df.dropna(axis=0,inplace=True)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %% [markdown]
# #### Fix data type of pickup_datetime from `Categorical` to `DateTime format`

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce')

# %% [markdown]
# #### Separating the date and time into separate columns for more usability.

# %%
df= df.assign(
    second = df.pickup_datetime.dt.second,
    minute = df.pickup_datetime.dt.minute,
    hour = df.pickup_datetime.dt.hour,
    day= df.pickup_datetime.dt.day,
    month = df.pickup_datetime.dt.month,
    year = df.pickup_datetime.dt.year,
    dayofweek = df.pickup_datetime.dt.dayofweek
)
df = df.drop('pickup_datetime',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_longitude   199999 non-null  float64
#  2   pickup_latitude    199999 non-null  float64
#  3   dropoff_longitude  199999 non-null  float64
#  4   dropoff_latitude   199999 non-null  float64
#  5   passenger_count    199999 non-null  int64
#  6   second             199999 non-null  int64
#  7   minute             199999 non-null  int64
#  8   hour               199999 non-null  int64
#  9   day                199999 non-null  int64
#  10  month              199999 non-null  int64
#  11  year               199999 non-null  int64
#  12  dayofweek          199999 non-null  int64
# dtypes: float64(5), int64(8)
# memory usage: 21.4 MB

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek
# 0          3
# 1          4
# 2          0
# 3          4
# 4          3

# %% [markdown]
# ## **Haversine Formula**
# Calculatin the distance between the pickup and drop co-ordinates using the Haversine formual for accuracy.

# %%
incorrect_coordinates = df.loc[
    (df.pickup_latitude > 90) |(df.pickup_latitude < -90) |
    (df.dropoff_latitude > 90) |(df.dropoff_latitude < -90) |
    (df.pickup_longitude > 180) |(df.pickup_longitude < -180) |
    (df.dropoff_longitude > 90) |(df.dropoff_longitude < -90)
]

df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')

# %%
def distance_transform(longitude1, latitude1, longitude2, latitude2):
    long1, lati1, long2, lati2 = map(np.radians, [longitude1, latitude1, longitude2, latitude2])
    dist_long = long2 - long1
    dist_lati = lati2 - lati1
    a = np.sin(dist_lati/2)**2 + np.cos(lati1) * np.cos(lati2) * np.sin(dist_long/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) * 6371
    # long1,lati1,long2,lati2 = longitude1[pos],latitude1[pos],longitude2[pos],latitude2[pos]
    # c = sqrt((long2 - long1) ** 2 + (lati2 - lati1) ** 2)asin 
       
    return c

# %%
df['Distance'] = distance_transform(
    df['pickup_longitude'],
    df['pickup_latitude'],
    df['dropoff_longitude'],
    df['dropoff_latitude']
)

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek  Distance
# 0          3  1.683323
# 1          4  2.457590
# 2          0  5.036377
# 3          4  1.661683
# 4          3  4.475450

# %% [markdown]
# ## **Outliers**
#  trips with very large distances and trips with 0 distance  are outliers

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20)) #Boxplot to check the outliers
plt.show()

# %%
def remove_outlier(df1 , col):
    Q1 = df1[col].quantile(0.25)
    Q3 = df1[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_whisker = Q1-1.5*IQR
    upper_whisker = Q3+1.5*IQR
    df[col] = np.clip(df1[col] , lower_whisker , upper_whisker)
    return df1

def treat_outliers_all(df1 , col_list):
    for c in col_list:
        df1 = remove_outlier(df , c)
    return df1

# %%
df = treat_outliers_all(df , df.iloc[: , 0::])

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20)) #Boxplot to check the outliers
plt.show()

# %% [markdown]
# ## **Coorelation Matrix**

# %%
corr = df.corr()

corr.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_45fcb_row0_col0, #T_45fcb_row1_col1, #T_45fcb_row1_col3, #T_45fcb_row2_col2, #T_45fcb_row3_col1, #T_45fcb_row3_col3, #T_45fcb_row4_col4, #T_45fcb_row5_col5, #T_45fcb_row6_col6, #T_45fcb_row7_col7, #T_45fcb_row8_col8, #T_45fcb_row9_col9, #T_45fcb_row10_col10, #T_45fcb_row11_col11, #T_45fcb_row12_col12, #T_45fcb_row13_col13 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_45fcb_row0_col1, #T_45fcb_row0_col3, #T_45fcb_row7_col1, #T_45fcb_row7_col3, #T_45fcb_row8_col1, #T_45fcb_row8_col3, #T_45fcb_row9_col1, #T_45fcb_row9_col3, #T_45fcb_row10_col4, #T_45fcb_row11_col1, #T_45fcb_row11_col3, #T_45fcb_row12_col1, #T_45fcb_row12_col3 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_45fcb_row0_col2, #T_45fcb_row7_col2, #T_45fcb_row9_col2, #T_45fcb_row9_col4, #T_45fcb_row11_col2, #T_45fcb_row11_col4, #T_45fcb_row12_col2 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_45fcb_row0_col4, #T_45fcb_row5_col1, #T_45fcb_row5_col2, #T_45fcb_row5_col3, #T_45fcb_row5_col4, #T_45fcb_row7_col4, #T_45fcb_row8_col2, #T_45fcb_row8_col4, #T_45fcb_row10_col1, #T_45fcb_row10_col2, #T_45fcb_row10_col3, #T_45fcb_row12_col4 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_45fcb_row0_col5, #T_45fcb_row6_col11, #T_45fcb_row10_col5 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_45fcb_row0_col6, #T_45fcb_row2_col5, #T_45fcb_row4_col5, #T_45fcb_row9_col6 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_45fcb_row0_col7, #T_45fcb_row1_col2, #T_45fcb_row1_col4, #T_45fcb_row1_col13, #T_45fcb_row3_col2, #T_45fcb_row3_col4, #T_45fcb_row3_col13, #T_45fcb_row4_col1, #T_45fcb_row4_col3, #T_45fcb_row5_col6, #T_45fcb_row6_col5, #T_45fcb_row8_col0, #T_45fcb_row8_col12, #T_45fcb_row10_col9, #T_45fcb_row10_col11, #T_45fcb_row11_col10, #T_45fcb_row12_col8, #T_45fcb_row13_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_45fcb_row0_col8, #T_45fcb_row6_col10 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_45fcb_row0_col9, #T_45fcb_row6_col0, #T_45fcb_row7_col9, #T_45fcb_row13_col9 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_45fcb_row0_col10, #T_45fcb_row10_col6 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_45fcb_row0_col11 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_45fcb_row0_col12, #T_45fcb_row1_col12, #T_45fcb_row3_col12, #T_45fcb_row9_col8, #T_45fcb_row9_col10, #T_45fcb_row9_col12, #T_45fcb_row11_col12 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_45fcb_row0_col13 {
#   background-color: #006d2c;
#   color: #f1f1f1;
# }
# #T_45fcb_row1_col0, #T_45fcb_row1_col9, #T_45fcb_row3_col0, #T_45fcb_row3_col9, #T_45fcb_row5_col9, #T_45fcb_row8_col9, #T_45fcb_row9_col0, #T_45fcb_row12_col0, #T_45fcb_row12_col9 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_45fcb_row1_col5, #T_45fcb_row3_col5, #T_45fcb_row7_col5, #T_45fcb_row7_col6, #T_45fcb_row9_col5, #T_45fcb_row12_col6, #T_45fcb_row13_col6 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_45fcb_row1_col6, #T_45fcb_row3_col6, #T_45fcb_row8_col6 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_45fcb_row1_col7, #T_45fcb_row2_col1, #T_45fcb_row2_col3, #T_45fcb_row2_col7, #T_45fcb_row2_col9, #T_45fcb_row3_col7, #T_45fcb_row4_col7, #T_45fcb_row4_col9, #T_45fcb_row5_col7, #T_45fcb_row6_col7, #T_45fcb_row8_col7, #T_45fcb_row9_col7, #T_45fcb_row10_col7, #T_45fcb_row11_col7, #T_45fcb_row11_col9, #T_45fcb_row12_col7 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_45fcb_row1_col8, #T_45fcb_row2_col8, #T_45fcb_row3_col8, #T_45fcb_row4_col8, #T_45fcb_row6_col12, #T_45fcb_row7_col8, #T_45fcb_row11_col8 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_45fcb_row1_col10, #T_45fcb_row2_col11, #T_45fcb_row3_col10, #T_45fcb_row4_col11, #T_45fcb_row7_col11, #T_45fcb_row7_col13, #T_45fcb_row8_col10, #T_45fcb_row12_col10, #T_45fcb_row13_col12 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_45fcb_row1_col11, #T_45fcb_row2_col10, #T_45fcb_row3_col11, #T_45fcb_row4_col10, #T_45fcb_row5_col11, #T_45fcb_row6_col13, #T_45fcb_row7_col10, #T_45fcb_row8_col11, #T_45fcb_row9_col13, #T_45fcb_row12_col11 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_45fcb_row2_col0, #T_45fcb_row4_col0, #T_45fcb_row6_col9, #T_45fcb_row7_col0 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_45fcb_row2_col4, #T_45fcb_row4_col2 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_45fcb_row2_col6, #T_45fcb_row4_col6, #T_45fcb_row8_col5 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_45fcb_row2_col12, #T_45fcb_row4_col12, #T_45fcb_row7_col12, #T_45fcb_row8_col13, #T_45fcb_row10_col8 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_45fcb_row2_col13 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_45fcb_row4_col13 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_45fcb_row5_col0 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_45fcb_row5_col8, #T_45fcb_row9_col11 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_45fcb_row5_col10, #T_45fcb_row5_col12, #T_45fcb_row5_col13, #T_45fcb_row10_col13, #T_45fcb_row13_col10 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_45fcb_row6_col1, #T_45fcb_row6_col3 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# #T_45fcb_row6_col2 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_45fcb_row6_col4 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_45fcb_row6_col8, #T_45fcb_row10_col12 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_45fcb_row10_col0 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_45fcb_row11_col0 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_45fcb_row11_col5, #T_45fcb_row13_col5 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_45fcb_row11_col6 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_45fcb_row11_col13, #T_45fcb_row13_col11 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_45fcb_row12_col5 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_45fcb_row12_col13 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_45fcb_row13_col0 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_45fcb_row13_col1, #T_45fcb_row13_col3 {
#   background-color: #80cdb7;
#   color: #000000;
# }
# #T_45fcb_row13_col2, #T_45fcb_row13_col4 {
#   background-color: #57ba92;
#   color: #f1f1f1;
# }
# #T_45fcb_row13_col8 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# </style>
# <table id="T_45fcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45fcb_level0_col0" class="col_heading level0 col0" >fare_amount</th>
#       <th id="T_45fcb_level0_col1" class="col_heading level0 col1" >pickup_longitude</th>
#       <th id="T_45fcb_level0_col2" class="col_heading level0 col2" >pickup_latitude</th>
#       <th id="T_45fcb_level0_col3" class="col_heading level0 col3" >dropoff_longitude</th>
#       <th id="T_45fcb_level0_col4" class="col_heading level0 col4" >dropoff_latitude</th>
#       <th id="T_45fcb_level0_col5" class="col_heading level0 col5" >passenger_count</th>
#       <th id="T_45fcb_level0_col6" class="col_heading level0 col6" >second</th>
#       <th id="T_45fcb_level0_col7" class="col_heading level0 col7" >minute</th>
#       <th id="T_45fcb_level0_col8" class="col_heading level0 col8" >hour</th>
#       <th id="T_45fcb_level0_col9" class="col_heading level0 col9" >day</th>
#       <th id="T_45fcb_level0_col10" class="col_heading level0 col10" >month</th>
#       <th id="T_45fcb_level0_col11" class="col_heading level0 col11" >year</th>
#       <th id="T_45fcb_level0_col12" class="col_heading level0 col12" >dayofweek</th>
#       <th id="T_45fcb_level0_col13" class="col_heading level0 col13" >Distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45fcb_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_45fcb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_45fcb_row0_col1" class="data row0 col1" >0.005885</td>
#       <td id="T_45fcb_row0_col2" class="data row0 col2" >-0.006253</td>
#       <td id="T_45fcb_row0_col3" class="data row0 col3" >0.005501</td>
#       <td id="T_45fcb_row0_col4" class="data row0 col4" >-0.00

# %% [markdown]
# # **Standardization**
# For more accurate results on our linear regression model

# %%
X = df['Distance'].values.reshape(-1, 1)        #Independent Variable
y = df['fare_amount'].values.reshape(-1, 1)     #Dependent Variable

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
y_std = std.fit_transform(y)
print(y_std)

x_std = std.fit_transform(X)
print(x_std)
# Out:
# [[-0.39820843]
#  [-0.37738556]
#  [ 0.1640092 ]
#  ...
#  [ 2.03806797]
#  [ 0.3305922 ]
#  [ 0.28894645]]
# [[-0.43819769]
#  [-0.22258873]
#  [ 0.49552213]
#  ...
#  [ 2.67145829]
#  [ 0.07874908]
#  [ 0.60173174]]

# %% [markdown]
# # **Splitting the Dataset**
# Training and Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.2, random_state=0)

# %% [markdown]
# # **Simple Linear Regression**
# Training the simple linear regression model on the training set

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train, y_train)

print("Training set score: {:.2f}".format(l_reg.score(X_train, y_train)))
print("Test set score: {:.7f}".format(l_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.74
# Test set score: 0.7340468

# %%
y_pred = l_reg.predict(X_test)

result = pd.DataFrame()
result[['Actual']] = y_test
result[['Predicted']] = y_pred

result.sample(10)
# Out:
#          Actual  Predicted
# 1586  -0.793843  -0.620453
# 37532  0.486764   0.675611
# 26419 -0.419031  -0.402792
# 21163 -0.627260  -0.284156
# 17494 -0.085865  -0.216788
# 4642  -0.606437  -0.624304
# 15943  0.913633   1.635102
# 30692 -0.543969  -0.452376
# 36486  0.080718   0.211365
# 14131  2.204651   2.036509

# %%
print("Linear Regresion model")
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R-sqyuared: ",np.sqrt(metrics.r2_score(y_test, y_pred)))
# Out:
# Linear Regresion model
# RMSE:  0.5201195546005304
# R-sqyuared:  0.8567653080822022

# %% [markdown]
# # **RandomForestRegressor**
# Training the RandomForestRegressor model on the training set

# %%
rf_reg = RandomForestRegressor(n_estimators=100, random_state=10)

# fit the regressor with training dataset
rf_reg.fit(X_train, y_train)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_25172\2264728154.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_reg.fit(X_train, y_train)
# RandomForestRegressor(random_state=10)

# %%
# predict the values on test dataset using predict()
y_pred_RF = rf_reg.predict(X_test)

result = pd.DataFrame()
result[['Actual']] = y_test
result['Predicted'] = y_pred_RF

result.sample(10)
# Out:
#          Actual  Predicted
# 521   -0.543969  -0.498158
# 13913 -0.002574  -0.075037
# 30267  0.174421  -0.047031
# 38860  0.413884  -0.724399
# 17619  0.080718  -0.395710
# 21977 -0.543969  -0.308878
# 9683  -0.502323  -0.467965
# 11157 -0.085865  -0.621013
# 23951  0.226478   0.270310
# 4599  -0.137922  -0.242662

# %%
print("Random Forest Regressor model")
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred_RF)))
# Out:
# Random Forest Regressor model
# Root Mean Squared Error: 0.5770418791876677
# R Squared (R²): 0.8201518783882692
